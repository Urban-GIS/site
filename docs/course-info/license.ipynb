# %% [markdown]
# # Licence and terms of use
#
# The teaching materials on this course website are shared so that students,
# teachers, and others can use them as a learning and reference resource.
# **This material is not open source or open content in the Creative Commons
# sense: it may be read, referenced, and cited, but not copied, redistributed,
# or adapted without permission.** See below for the exact terms.
#
# <div style="background-color: #f0f4f8; border-left: 5px solid #0078D4; padding: 20px; margin: 20px 0;">
#   This course was created by
#   <a href="https://www.kamyarhz.com/">Kamyar Hasanzadeh</a>,
#   University Lecturer in Geoinformatics and Docent in Urban Informatics at the University of Helsinki.
#   Its development was supported by the
#   <a href="https://www.helsinki.fi/en/degree-programmes/urban-studies-and-planning-masters-programme">
#     Master’s Programme in Urban Studies and Planning (USP)
#   </a>.
# </div>
#
#
# ## Instructional material
#
# © 2025 Kamyar Hasanzadeh, Department of Geosciences and Geography,
# University of Helsinki, and the Master’s Programme in Urban Studies and
# Planning (USP). All rights reserved.
#
# Unless otherwise stated, the written material, instructions, figures, and
# other teaching content in *Urban GIS and Visual Tools* is made publicly
# available for **individual learning and reference**. You may:
#
# - **read and study** the material for your own personal learning, and
# - **link to and cite** it (with appropriate attribution) as a teaching
#   resource, for example in a syllabus, reading list, or article.
#
# You may **not**, without prior written permission:
#
# - **copy, mirror, or redistribute** the material, in whole or in part, on
#   another website, repository, or platform,
# - **adapt, remix, translate, or build upon** the material to create your own
#   or a derivative course, textbook, or teaching resource, or
# - **use the material commercially**, including as part of a paid course or
#   training.
#
# Please do not imply that the University of Helsinki, the Master’s Programme
# in Urban Studies and Planning, or the course staff endorses your use of the
# material.
#
# If you would like to reuse, adapt, or build on this material beyond what is
# described above &mdash; for instance, to teach it at your own institution or
# to publish a derivative version &mdash; please contact the course teacher
# through the [general information page](general-info.ipynb) to request
# permission.
#
# ## Code and software
#
# Unless otherwise stated, code snippets, expressions, scripts, and other
# software provided specifically through this course are shown for
# illustration alongside the instructional material above, and are covered by
# the same terms: they may be read and studied, but not copied, redistributed,
# or reused in other projects or courses without prior written permission.
#
# ## Third-party data and material
#
# Course exercises may use data, basemaps, imagery, or other resources supplied by third parties. Their own licences and terms of use apply. Always check the source and licence information provided with a dataset before reusing it outside the course.
#
# ## Feedback and contributions
#
# Suggestions, corrections, and improvements are welcome. Please contact the course teacher through the [general information page](general-info.ipynb).
