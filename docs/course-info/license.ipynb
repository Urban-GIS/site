# %% [markdown]
# # Licence and terms of use
#
# The teaching materials on this open course website are shared so that students, teachers, and others can use and build on them. If you reuse or adapt any part of the material, please acknowledge this course as the source and share your adapted material openly.
#
# <div style="background-color: #f0f4f8; border-left: 5px solid #0078D4; padding: 20px; margin: 20px 0;">
#   This open-access course was created by
#   <a href="https://www.kamyarhz.com/">Kamyar Hasanzadeh</a>,
#   University Lecturer in Geoinformatics and Docent in Urban Informatics at the University of Helsinki.
#   Its development was supported by the
#   <a href="https://www.helsinki.fi/en/degree-programmes/urban-studies-and-planning-masters-programme">
#     Master’s Programme in Urban Studies and Planning (USP)
#   </a>.
# </div>
#
#
# ## Instructional material
#
# Unless otherwise stated, the written material, instructions, figures, and other teaching content in *Urban GIS and Visual Tools* are available under a [Creative Commons Attribution-ShareAlike 4.0 International licence](https://creativecommons.org/licenses/by-sa/4.0/).
#
# This licence allows you to:
#
# - **share**: copy and redistribute the material in any medium or format; and
# - **adapt**: remix, transform, and build upon the material for any purpose, including commercially.
#
# These permissions apply provided that you:
#
# - **give appropriate credit**, link to the licence, and indicate whether you made changes;
# - **share adaptations under the same licence**; and
# - **do not add legal or technical restrictions** that prevent others from using the material as the licence permits.
#
# Please do not imply that the University of Helsinki or the course staff endorses your use of the material.
#
# ## Code and software
#
# Unless otherwise stated, code snippets, expressions, scripts, and other software provided specifically through this course are available under the [GNU General Public License, version 3](https://www.gnu.org/licenses/gpl-3.0.html).
#
# ## Third-party data and material
#
# Course exercises may use data, basemaps, imagery, or other resources supplied by third parties. Their own licences and terms of use apply. Always check the source and licence information provided with a dataset before reusing it outside the course.
#
# ## Feedback and contributions
#
# Suggestions, corrections, and improvements are welcome. Please contact the course teacher through the [general information page](general-info.ipynb).
