# %% [markdown]
# # Course overview and schedule
#
# Course schedule • Autumn 2026 • Wednesdays, 2 September–9 December
#
# | Date       | Topic / Practical            | Key Activities / Notes                                                      | Location                  |
# | ---------- | ---------------------------- | --------------------------------------------------------------------------- | ------------------------- |
# | **02.09.** | **GIS Bootcamp      I**      | Intro to QGIS, adding data, variables, visualizing maps                     | Main Building, **F3005**  |
# | **09.09.** | **GIS Bootcamp      II**     | Spreadsheet data, spatial join, vector clipping, heat maps                  | Main Building, **F3005**  |
# | **16.09.** | **Practical 1**              | Choose one: open datasets, noise analysis, historical GIS, raster maps      | Main Building, **F3005**  |
# | **23.09.** | **Practical 2**              | Zonal statistics, population pressure, green areas                          | Main Building, **F3005**  |
# | **30.09.** | **Practical 3**              | Building register data, density analysis, defining centrality               | Main Building, **F3005**  |
# | **07.10.** | **Practical 4**              | Socioeconomic structure: grid database analysis • Guest visit               | Main Building, **F3005**  |
# | **14.10.** | **Practical 5**              | Urban planning: industry clusters in Helsinki (YKR data) • Guest visit      | Main Building, **F3005**  |
# | **21.10.** | **No class**                 | Autumn break                                                                | No meeting                |
# | **28.10.** | **Practical 6**              | SoftGIS / PPGIS: analyzing SoftGIS datasets                                 | Main Building, **F3005**  |
# | **04.11.** | **Practical 7**              | Accessibility and GIS: Helsinki metropolitan region • Guest visit           | Main Building, **F3005**  |
# | **11.11.** | **Practical 8**              | GIS automation: QGIS Model Builder • Guest visit •                          | Main Building, **F3005**  |
# | **18.11.** | **Practical 9**              | Prioritizing urban green areas through patch-based indicators • Guest visit | Main Building, **F3005**  |
# | **25.11.** | **Practical 10**             | Exporting data, web publishing                                              | Main Building, **F3005**  |
# | **02.12.** | **Final Report Workshop I**  | Final report workshop and teacher support                                   | Language Centre, **S115** |
# | **09.12.** | **Final Report Workshop II** | Continued work and teacher support (presentations)                          | Main Building, **F3005**  |
#
# > **Note:** The schedule and topics are indicative and may change as the course progresses.
