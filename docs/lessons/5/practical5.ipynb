# %% [markdown]
# # Practical 5
#
# ## GIS Aand Urban Planning: Hotspot Analysis
#
# ### OVERVIEW & PURPOSE
#
# Spatial phenomena tend to vary in intensity across a geographical area. **When the occurrence
# of a certain phenomenon is significantly higher in one area than in the surrounding area,
# you could describe it as a “hotspot” for that phenomenon.** For instance, cities are hotspots
# of buildings and human activity, forests are hotspots of trees etc. There are many ways to
# locate these hotspots: *interpolation, cluster analysis,* and *heatmap analysis*, to name a few.
# Today we’re taking a look at road traffic accidents in the Helsinki metropolitan area with heatmaps and heatmap analysis. Your task is to identify accident hotspots using point-based accident data and create a diagram distribution of traffic accidents in Helsinki metropolitan area.
#
# As the name would suggest, heatmaps describe the “heat,” or intensity, of the phenomenon
# in question. Heatmaps are generated with point feature data and form a raster layer. In its
# most rudimentary form, the pixel values of a heatmap depict proximity to other point features
# within a certain, user-specified, radius. A slightly more advanced form of heatmaps can be
# given a weight (from the point features’ attribute table) that will influence the pixel values.
#
# For instance, two heatmaps are created out of the same point feature layer (bus stops). One
# heatmap wasn’t given a weight, so it only looks for other bus stops within a certain radius, e.g.
# 500 meters. The other was given a weight, e.g. daily passenger amount, from the attribute
# table of the bus stops layer. To generate this other heatmap, the GIS software not only looks
# for bus stops within a radius of 500 meters of each other, but also gives the bus stops with
# higher passenger amounts a higher weight. Thus, the bus stops with a high daily passenger
# amount will be “favored” in the resulting heatmap raster layer.
#
# One step more advanced form of heatmap will also include modification of the kernel shape.
# Kernel is the statistical function used to give proximity and weight scores to the point features
# within the radius. Heatmaps are also known as kernel density analysis.
#
# **What happens in Kernel Density Analysis?**
#
# To understand the basic idea of Kernel Density Analysis that we use to create a heatmap, you
# can watch this 9-minute-long video (Point Pattern Analysis Part 5: Kernel Density Estimation): https://www.youtube.com/watch?v=PBZVTjmhl74
#
#
# When applying the kernel method, QGIS draws a **circular neighborhood around each sample
# point** (not each cell) and then applies a math function that goes from 1 at the location of the
# point to 0 at the neighborhood boundary. Think of a kernel as a **smoothly curved surface that
# is fitted over each point.**
#
#
#    <img src="figures/figure1.png" width="300">
#
#
#
# **Figure 1**: In density calculations, the size of the kernel is determined by the size of the search radius,
# which is centered on a sample point. The larger the search radius, the flatter the kernel.
#
# When a kernel function is applied to each data point, the effect is like that of an elevation
# surface, except that the density value for each cell is calculated by adding the values of all the
# kernel surfaces where they overlay the cell center.
#
#    <img src="figures/figure2.png" width="300">
#
# **Figure 2**: Density calculations with more than one sample points.
#
#
#
#
# ### OBJECTIVES
# 1. Master the process of creating **heatmaps** using Kernel Density Estimation in QGIS.
# 2. Compile **five heatmaps**:
#    a. One depicting the total number of accidents.
#    b. Four heatmaps representing different road user groups involved in accidents.
# 3. Create a **diagram** (e.g., column chart, pie chart) showing he distribution of road traffic accident involvement in the Helsinki metropolitan area by road user and vehicle type.
# 4. Critically **analyze and compare** the resulting maps and diagram to understand the spatial patterns of road traffic accidents in the Helsinki metropolitan area.
#
#
#
# ### DATA USED/NEEDED
#
# **Statistics Finland's road traffic accident point data (2024)**
#
# **Optional Background Map:**
#    a. Use the QuickMapServices plugin or data from the Crash Course folder for context.
#
#
#
# The attribute table’s field names are in Finnish, underneath you’ll find the translations:
#
#
#
#    <img src="figures/taulukko1.png" width="600">
#
#
# ***Table 1:*** *Translations of the field names into English. Data source: https://stat.fi/en/services/statistical-data-services/geographic-data/road-traffic-accidents*
#
# ### COMPLETION
# Complete the exercise and write a short report together (2-3 pages of text + Maps) containing
# at least the following:
# 1. **Maps:** Five maps visualizing accident hotspots in the Helsinki metropolitan area.
#    a. Remember map elements
# 2. **Diagram:** One diagram (e.g. bar chart or pie chart) depicting the distribution of road traffic accidents in the Helsinki metropolitan area by road user and vehicle type.
# 3. **A Process Description:** A description of how you created your maps and diagram.
#    a. What QGIS, Spreadsheet tools and settings did you use?
#    b. What parts of the process were difficult or easy?
# 4. **Analysis of the Results:**
#    a. Why do you think road traffic accidents cluster in certain areas of the Helsinki metropolitan area?
#    b. Which accident types occur in similar locations? Which are far apart? Why
# might this be?
#    c. How did altering the radius and kernel shape affect the heatmaps?
#    d. What does the accident structure diagram show about which road user groups are most involved in accidents in the Helsinki metropolitan area?
#
# 5. **Submission:** Submit a single PDF containing representative screenshots of your completed tutorial. Screenshots do not need to show every step, but they should clearly cover the main stages of the workflow.

# %% [markdown]
# ### EXERCISE PHASES
# ***Getting familiar with the data***
#
# *Before starting any analysis, it is crucial to understand your dataset's structure, variables, and
# potential limitations. This ensures you ask the right questions and use the data correctly.*
#
#
# 1. **Download, unzip and open the practical 5 data**
#    a. Make sure the CRS is correct for the accident layer! (EPSG: 3067)
#
# 2. **It’s good practice to go through the attribute tables of your data** (if they have any) to
# get a grip on what you’re working with
#    a. Many field names are in Finnish, use the table above to decipher their
# meanings.
#    b. We’re analyzing the whole of Helsinki metropolitan region, there’s *no need for
# any clipping* during this exercise.
#
#
# 3. **You might want to have a background map to help you get your bearings.**
#    a. You can use OpenLayers, QuickMapServices, the spatial data from the Crash
# Course’s main folder, or your own data.
#
#
#
#
# ***Creating a heatmap***
#
# *A heatmap transforms point data into a continuous raster surface, showing where events are concentrated. Using a “weight” (like the number of accidents) ensures that areas with more accidents in a single location create a “hotter” spot than areas where accidents are more spread out.*
#
# 4. There’re a few ways to create a heatmap in QGIS. We’re going to use the one found in
# the *Processing toolbox*.
#
# The other out-of-the-box heatmap creation method in QGIS is the virtual heatmap
# creation (found under Symbology tab of the properties of any point feature layer). This
# method is purely visual – you can use it to style a map, but not export it as a raster
# layer.
#
# 5. Open *Heatmap (Kernel Density Estimation)*. You will find it the Processing Toolbox,
# under Interpolation.
#
# **You will create separate heatmaps for different categories of road users involved in accidents.**
#
# First let’s create a heatmap depicting the locations of all accidents in the Helsinki metropolitan region.
#
# a. Make sure input layer is correct.
# b. **Set radius to 1000 meters** for now.
# c. **Set Pixel sizes to 20 m x 20 m** (pixel size = cell size)
# d. From the Advanced Parameters menu:
# I. Leave the weight fiel empty
# II. The kernel shape can be left at Quartic (biweight) for now.
# III. Leave output values as raw.
# e. Specify the destination and filename for the output layer (output is raster).
#    Name it informatively. Check that you don’t use blank spaces or special
#    characters in file or folder names, that may cause errors.
# f. Click Run to create the heatmap.
#
# ***Hint:*** *in this case each point represents a single accident, so no weight field is required.*
#
# 6. **Before creating heatmaps for the types of road users involved in accidents, experiment with heatmap creation by using the same settings as in the previous step but change radius or kernel shape. How do the results change?**
#
# ***Hint:*** *The heatmap radius shows how far each point “spreads” its influence around it. Larger values result in greater smoothing, but smaller values may show finer details and variation in point density. Kernel shape controls the rate at which the influence of a point decreases as the distance from the point increases and this changes how the hotspots look. Some kernels (like triweight) keep the influence stronger near the point, creating sharper hotspots.
# Others (like Epanechnikov) spread the influence more smoothly, creating softer hotspots.*
#
# a. Now create four heatmaps representing different types of road users involved in accidents. Use the fields *lkmhapa, lkmjk, lkmpp* and one additional field of your choice as weight. Use the same settings for all layers (e.g., 1000 m radius and quartic kernel shape).
#
# b. Visualize each heatmap on a separate map.
#
#
#
# *Tip: Use Singleband pseudocolor from the layer Symbology to apply a color ramp and improve visualization.*
#
# *Additional tip: You can adjust layer transparency or set low values (e.g., 0) to be more transparent to better highlight the main hotspots. You can also adjust the transparency of the map layers in symbology.*

# %% [markdown]
# ***Creating a diagram***
#
# 7. Select all points representing traffic accidents in the Helsinki metropolitan area and save the selection as a separate shapefile.
#
#    a. Give it informative name
#
#    b. Save your project and close QGIS
#
#
# 8. Using Excel, LibreOffice or OpenOffice (Mac users: use LibreOffice or OpenOffice!), go to the folder you saved the new shapefile layer and open the .dbf file. You should save the opened .dbf file as a new spreadsheet file (so not as .dbf), if you want to make sure you can use the shapefile layer later.
#
# 9. Create an informative diagram/chart that depicts road traffic accident involvement by road user and vehicle type within the Helsinki metropolitan area, and include it in your report.
#
#     a. Column diagram or a pie chart will suffice
#
#     b. Make sure you give the fields actual names instead of the original field names.
#
# *Tip: you can use a pivot table to sum the values in each field before making the chart.*
#
#
# 10. Write your report according to the instructions in ***Completion*** section above
#
# ### Submission
#
# Submit a single PDF containing representative screenshots of your completed tutorial. Screenshots do not need to show every step, but they should clearly cover the main stages of the workflow.
